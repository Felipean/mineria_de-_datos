# %%
import pandas as pd
import matplotlib.pyplot as plt
get_ipython().magic(u'matplotlib inline') 
get_ipython().magic(u"config InlineBackend.figure_format='retina'")
import os
import numpy as np
import numpy as n
import seaborn as sb
import matplotlib.pyplot as plt
IB = os.environ.get('INSTABASE_URI',None) is not None
open = ib.open if IB else open

# %%
#MOSTRAMOS LA SABANA DE DATOS ("ABANDONO DE EMPLEO").
x = open('WA_Fn-UseC_-HR-Employee-Attrition.csv', 'rU')
data = pd.read_csv(x)
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# 0          ...                                  1            80
# 1          ...                                  4            80
# 2          ...                                  2            80
# 3          ...                                  3            80
# 4          ...                                  4            80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                  8                      0               1
# 1                 1                 10                      3               3
# 2                 0                  7                      3               3
# 3                 0                  8                      3               3
# 4                 1                  6                      3               3
#
#    YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                  4                        0
# 1              10                  7                        1
# 2               0                  0                        0
# 3               8                  7                        3
# 4               2                  2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 35 columns]

# %%
#GENERO UN RANGO ESTARIO CON 1=(18-30); 2=(31-45); 3=(46-60). 
bins = [18,30,45,60]
names = ["1","2","3"]
data["Age"] = pd.cut(data["Age"], bins, labels = names)

# %%
#CON ESTO REMPLAZAMOS LOS NOMBRES DE BUSINESSTRAVEL Travel_Frequently(1) ;Travel_Rarely(2) ;Non-Travel(3)
#ATTRITION POR Yes(1); No(0).
data.replace({'BusinessTravel': {"Travel_Frequently": 2,"Travel_Rarely": 1, "Non-Travel": 0 }},  inplace = True)
data.replace({'Attrition' : {"Yes" : 1, "No" : 0}}, inplace = True)
data.head()
# Out:
#   Age  Attrition  BusinessTravel  DailyRate              Department  \
# 0   2          1               1       1102                   Sales
# 1   3          0               2        279  Research & Development
# 2   2          1               1       1373  Research & Development
# 3   2          0               2       1392  Research & Development
# 4   1          0               1        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# 0          ...                                  1            80
# 1          ...                                  4            80
# 2          ...                                  2            80
# 3          ...                                  3            80
# 4          ...                                  4            80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                  8                      0               1
# 1                 1                 10                      3               3
# 2                 0                  7                      3               3
# 3                 0                  8                      3               3
# 4                 1                  6                      3               3
#
#    YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                  4                        0
# 1              10                  7                        1
# 2               0                  0                        0
# 3               8                  7                        3
# 4               2                  2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 35 columns]

# %%
#OBTENER LOS NOMBRES DE LAS COLUMNAS COMO LISTA
names = data.columns.tolist()
for column in names:
    print "Valores Nulos en <{0}>: <{1}>".format(column, data[column].isnull().sum())
# Out:
# Valores Nulos en <Age>: <8>
# Valores Nulos en <Attrition>: <0>
# Valores Nulos en <BusinessTravel>: <0>
# Valores Nulos en <DailyRate>: <0>
# Valores Nulos en <Department>: <0>
# Valores Nulos en <DistanceFromHome>: <0>
# Valores Nulos en <Education>: <0>
# Valores Nulos en <EducationField>: <0>
# Valores Nulos en <EmployeeCount>: <0>
# Valores Nulos en <EmployeeNumber>: <0>
# Valores Nulos en <EnvironmentSatisfaction>: <0>
# Valores Nulos en <Gender>: <0>
# Valores Nulos en <HourlyRate>: <0>
# Valores Nulos en <JobInvolvement>: <0>
# Valores Nulos en <JobLevel>: <0>
# Valores Nulos en <JobRole>: <0>
# Valores Nulos en <JobSatisfaction>: <0>
# Valores Nulos en <MaritalStatus>: <0>
# Valores Nulos en <MonthlyIncome>: <0>
# Valores Nulos en <MonthlyRate>: <0>
# Valores Nulos en <NumCompaniesWorked>: <0>
# Valores Nulos en <Over18>: <0>
# Valores Nulos en <OverTime>: <0>
# Valores Nulos en <PercentSalaryHike>: <0>
# Valores Nulos en <PerformanceRating>: <0>
# Valores Nulos en <RelationshipSatisfaction>: <0>
# Valores Nulos en <StandardHours>: <0>
# Valores Nulos en <StockOptionLevel>: <0>
# Valores Nulos en <TotalWorkingYears>: <0>
# Valores Nulos en <TrainingTimesLastYear>: <0>
# Valores Nulos en <WorkLifeBalance>: <0>
# Valores Nulos en <YearsAtCompany>: <0>
# Valores Nulos en <YearsInCurrentRole>: <0>
# Valores Nulos en <YearsSinceLastPromotion>: <0>
# Valores Nulos en <YearsWithCurrManager>: <0>

# %%
# Generar tabla de frecuencias
tab = pd.crosstab(index=data["Attrition"],columns="frecuencia")
print(tab)
# Out:
# col_0      frecuencia
# Attrition
# 0                1233
# 1                 237

# %%
#PORCENTAJE DE LOS QUE ABANDONAN V/S LOS QUE NO. 
tab = pd.crosstab(index=data["Attrition"],columns="frecuencia")
abandonan = tab.loc[tab.index == 1]["frecuencia"].sum()
no = tab.loc[tab.index == 0]["frecuencia"].sum()

data1 = np.array([abandonan,no])
plt.pie(data1,labels=["Los que si abandonan","Los que No abandonan"],autopct="%1.1f%%")
plt.xlabel("Abandonan")
plt.savefig("porcentaje_abandonan.png")

# %%
#CON ESTO GENERO UNA IDEA DE CUAL ES EL DEPARTAMENTO COM MAS EMPLEADOS. 
sb.factorplot('Department',data=data,kind="count")

# %%
data['BusinessTravel'].value_counts()
# Out:
# 1    1043
# 2     277
# 0     150
# Name: BusinessTravel, dtype: int64

# %%
#CON ESTO GENERO UNA IDEA DE CUALES SON LOS CAMPOS MAS ESTUDIADOS POR LOS EMPLEADOS.
sb.factorplot('EducationField',data=data,kind="count")

# %%
data['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
#CON ESTO GENERO UNA IDEA DE CUAL LA FRECUENCIA DE VIAJE DE LOS EMPLEADOS. 
sb.factorplot('BusinessTravel',data=data,kind="count")

# %%
#AGRUPO LAS TABLAS CON REFERENCIA CRUZADA PARA SABER CUANTOS SE FUERON DE CADA DEPARTAMENTO
pd.crosstab(data.Attrition, data.Department)
# Out:
# Department  Human Resources  Research & Development  Sales
# Attrition
# 0                        51                     828    354
# 1                        12                     133     92

# %%
#AGRUPO LAS TABLAS CON REFERENCIA CRUZADA PARA SABER LO QUE ESTUDIARON Y EN QUE TRABAJARON
pd.crosstab(data.EducationField, data.Department)
# Out:
# Department        Human Resources  Research & Development  Sales
# EducationField
# Human Resources                27                       0      0
# Life Sciences                  16                     440    150
# Marketing                       0                       0    159
# Medical                        13                     363     88
# Other                           3                      64     15
# Technical Degree                4                      94     34

# %%
#RELACION DE LA FRECUENCIA DE VIAJE DE LOS EMPLEADOS CON LOS DEPARTAMENOS DONDE TRABAJAN
pd.crosstab(data.BusinessTravel, data.Department)
# Out:
# Department      Human Resources  Research & Development  Sales
# BusinessTravel
# 0                             6                      97     47
# 1                            46                     682    315
# 2                            11                     182     84

# %%
EducationField_Department_BusinessTravel_Attrition_df = data.groupby(['EducationField','Department', 'BusinessTravel'])['Attrition'].sum()
EducationField_Department_BusinessTravel_Attrition_df
# Out:
# EducationField    Department              BusinessTravel
# Human Resources   Human Resources         0                  0
#                                           1                  4
#                                           2                  3
# Life Sciences     Human Resources         0                  0
#                                           1                  0
#                                           2                  1
#                   Research & Development  0                  3
#                                           1                 35
#                                           2                 21
#                   Sales                   0                  1
#                                           1                 18
#                                           2                 10
# Marketing         Sales                   0                  1
#                                           1                 26
#                                           2                  8
# Medical           Human Resources         0                  0
#                                           1                  2
#                                           2                  0
#                   Research & Development  0                  3
#                                           1                 33
#                                           2                 11
#                   Sales                   0                  1
#                                           1                 11
#                                           2                  2
# Other             Human Resources         1                  0
#                                           2                  0
#                   Research & Development  0                  0
#                                           1                  6
#                                           2                  1
#                   Sales                   0                  1
#                                           1                  1
#                                           2                  2
# Technical Degree  Human Resources         1                  2
#                   Research & Development  0                  2
#                                           1                 14
#                                           2                  4
#                   Sales                   0                  0
#                                           1                  4
#                                           2                  6
# Name: Attrition, dtype: int64

# %%
data['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
data.describe()
# Out:
#                Age    Attrition  BusinessTravel    DailyRate  \
# count  1470.000000  1470.000000     1470.000000  1470.000000
# mean     36.923810     0.161224        1.913605   802.485714
# std       9.135373     0.367863        0.532170   403.509100
# min      18.000000     0.000000        1.000000   102.000000
# 25%      30.000000     0.000000        2.000000   465.000000
# 50%      36.000000     0.000000        2.000000   802.000000
# 75%      43.000000     0.000000        2.000000  1157.000000
# max      60.000000     1.000000        3.000000  1499.000000
#
#        DistanceFromHome    Education  EmployeeCount  EmployeeNumber  \
# count       1470.000000  1470.000000         1470.0     1470.000000
# mean           9.192517     2.912925            1.0     1024.865306
# std            8.106864     1.024165            0.0      602.024335
# min            1.000000     1.000000            1.0        1.000000
# 25%            2.000000     2.000000            1.0      491.250000
# 50%            7.000000     3.000000            1.0     1020.500000
# 75%           14.000000     4.000000            1.0     1555.750000
# max           29.000000     5.000000            1.0     2068.000000
#
#        EnvironmentSatisfaction   HourlyRate          ...           \
# count              1470.000000  1470.000000          ...
# mean                  2.721769    65.891156          ...
# std                   1.093082    20.329428          ...
# min                   1.000000    30.000000          ...
# 25%                   2.000000    48.000000          ...
# 50%                   3.000000    66.000000          ...
# 75%                   4.000000    83.750000          ...
# max                   4.000000   100.000000          ...
#
#        RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# count               1470.000000         1470.0       1470.000000
# mean                   2.712245           80.0          0.793878
# std                    1.081209            0.0          0.852077
# min                    1.000000           80.0          0.000000
# 25%                    2.000000           80.0          0.000000
# 50%                    3.000000           80.0          1.000000
# 75%                    4.000000           80.0          1.000000
# max                    4.000000           80.0          3.000000
#
#        TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# count        1470.000000            1470.000000      1470.000000
# mean           11.279592               2.799320         2.761224
# std             7.780782               1.289271         0.706476
# min             0.000000               0.000000         1.000000
# 25%             6.000000               2.000000         2.000000
# 50%            10.000000               3.000000         3.000000
# 75%            15.000000               3.000000         3.000000
# max            40.000000               6.000000         4.000000
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count     1470.000000         1470.000000              1470.000000
# mean         7.008163            4.229252                 2.187755
# std          6.126525            3.623137                 3.222430
# min          0.000000            0.000000                 0.000000
# 25%          3.000000            2.000000                 0.000000
# 50%          5.000000            3.000000                 1.000000
# 75%          9.000000            7.000000                 3.000000
# max         40.000000           18.000000                15.000000
#
#        YearsWithCurrManager
# count           1470.000000
# mean               4.123129
# std                3.568136
# min                0.000000
# 25%                2.000000
# 50%                3.000000
# 75%                7.000000
# max               17.000000
#
# [8 rows x 28 columns]

# %%
#GUARDO UNA NUEVA TABLA CON LOS EMPLEADOS QUE SE FUERON(ATTRITION = YES).
import pandas as pd
x = open('WA_Fn-UseC_-HR-Employee-Attrition.csv', 'rU')
data = pd.read_csv(x)
d = (data[(data.Attrition == "Yes")])

# %%
#LOS GUARDO EN UNA TABLA LLAMADA "attrition.csv". 
d.to_csv('attrition.csv')

# %%
x = open('attrition.csv', 'rU')
attrition = pd.read_csv(x)
attrition = attrition.drop('Unnamed: 0', 1)
col_reg = list(attrition.columns.str.slice(0))
#Eliminar valores perdidos
attrition = attrition.dropna()
#Eliminar duplicados
attrition = attrition.drop_duplicates(subset=col_reg[1:][:-1], keep='last')
#Definir variable a predecir
attrition['MarcaA'] = 1
attrition.head(15)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    37       Yes      Travel_Rarely       1373  Research & Development
# 2    28       Yes      Travel_Rarely        103  Research & Development
# 3    36       Yes      Travel_Rarely       1218                   Sales
# 4    34       Yes      Travel_Rarely        699  Research & Development
# 5    32       Yes  Travel_Frequently       1125  Research & Development
# 6    39       Yes      Travel_Rarely        895                   Sales
# 7    24       Yes      Travel_Rarely        813  Research & Development
# 8    50       Yes      Travel_Rarely        869                   Sales
# 9    26       Yes      Travel_Rarely       1357  Research & Development
# 10   41       Yes      Travel_Rarely       1360  Research & Development
# 11   48       Yes      Travel_Rarely        626  Research & Development
# 12   28       Yes      Travel_Rarely       1434  Research & Development
# 13   36       Yes      Travel_Rarely        318  Research & Development
# 14   46       Yes      Travel_Rarely        669                   Sales
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                  1          2     Life Sciences              1
# 1                  2          2             Other              1
# 2                 24          3     Life Sciences              1
# 3                  9          4     Life Sciences              1
# 4                  6          1           Medical              1
# 5                 16          1     Life Sciences              1
# 6                  5          3  Technical Degree              1
# 7                  1          3           Medical              1
# 8                  3          2         Marketing              1
# 9                 25          3     Life Sciences              1
# 10                12          3  Technical Degree              1
# 11                 1          2     Life Sciences              1
# 12                 5          4  Technical Degree              1
# 13                 9          3           Medical              1
# 14                 9          2           Medical              1
#
#     EmployeeNumber   ...    StandardHours StockOptionLevel  TotalWorkingYears  \
# 0                1   ...               80                0                  8
# 1                4   ...               80                0                  7
# 2               19   ...               80                0                  6
# 3               27   ...               80                0                 10
# 4               31   ...               80                0                  8
# 5               33   ...               80                0                 10
# 6               42   ...               80                1                 19
# 7               45   ...               80                1                  6
# 8               47   ...               80                0                  3
# 9               55   ...               80                0                  1
# 10              58   ...               80                0                 23
# 11              64   ...               80                0                 23
# 12              65   ...               80                0                  2
# 13              90   ...               80                1                  2
# 14             118   ...               80                0                  9
#
#     TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                       0                1              6                   4
# 1                       3                3              0                   0
# 2                       4                3              4                   2
# 3                       4                3              5                   3
# 4                       2                3              4                   2
# 5                       5                3             10                   2
# 6                       6                4              1                   0
# 7                       2                2              2                   0
# 8                       2                3              3                   2
# 9                       2                2              1                   0
# 10                      0                3             22                  15
# 11                      2                3              1                   0
# 12                      3                2              2                   2
# 13                      0                2              1                   0
# 14                      3                3              9                   8
#
#    YearsSinceLastPromotion  YearsWithCurrManager  MarcaA
# 0                        0                     5       1
# 1                        0                     0       1
# 2                        0                     3       1
# 3                        0                     3       1
# 4                        1                     3       1
# 5                        6                     7       1
# 6                        0                     0       1
# 7                        2                     0       1
# 8                        0                     2       1
# 9                        0                     1       1
# 10                      15                     8       1
# 11                       0                     0       1
# 12                       2                     2       1
# 13                       0                     0       1
# 14                       4                     7       1
#
# [15 rows x 36 columns]

# %%
#CON ESTO GENERO UNA IDEA DE CUAL ES EL DEPARTAMENTO COM MAS EMPLEADOS. 
sb.factorplot('Department',data=attrition,kind="count")

# %%
#GENERO UN RANGO ESTARIO CON 1=(18-30); 2=(31-45); 3=(46-60). 
bins = [18,30,45,60]
names = ["1","2","3"]
attrition["Age"] = pd.cut(attrition["Age"], bins, labels = names)

# %%
#CON ESTO REMPLAZAMOS LOS NOMBRES DE BUSINESSTRAVEL Travel_Frequently(1) ;Travel_Rarely(2) ;Non-Travel(3)
#ATTRITION POR Yes(2); No(0).
attrition.replace({'BusinessTravel': {"Travel_Frequently": 1,"Travel_Rarely": 2, "Non-Travel": 3 }},  inplace = True)
attrition.replace({'Attrition' : {"Yes" : 1, "No" : 0}}, inplace = True)
attrition
# Out:
#     Age  Attrition  BusinessTravel  DailyRate              Department  \
# 0     2          1               2       1102                   Sales
# 1     2          1               2       1373  Research & Development
# 2     1          1               2        103  Research & Development
# 3     2          1               2       1218                   Sales
# 4     2          1               2        699  Research & Development
# 5     2          1               1       1125  Research & Development
# 6     2          1               2        895                   Sales
# 7     1          1               2        813  Research & Development
# 8     3          1               2        869                   Sales
# 9     1          1               2       1357  Research & Development
# 10    2          1               2       1360  Research & Development
# 11    3          1               2        626  Research & Development
# 12    1          1               2       1434  Research & Development
# 13    2          1               2        318  Research & Development
# 14    3          1               2        669                   Sales
# 15    2          1               2        807         Human Resources
# 16    1          1               1        871  Research & Development
# 17    1          1               2        240                   Sales
# 18    2          1               1        658  Research & Development
# 19    3          1               2        441  Research & Development
# 20    2          1               2        249                   Sales
# 21    3          1               2        147  Research & Development
# 22    1          1               2        528                   Sales
# 23    2          1               2        542                   Sales
# 24    3          1               1       1150  Research & Development
# 25    2          1               2       1033  Research & Development
# 26    1          1               1        602                   Sales
# 27    1          1               2        303  Research & Development
# 28    2          1               2       1356                   Sales
# 29    2          1               2        556  Research & Development
# ..   ..        ...             ...        ...                     ...
# 207   2          1               1        807  Research & Development
# 208   1          1               2        337                   Sales
# 209   1          1               2       1294  Research & Development
# 210   2          1               1        429  Research & Development
# 211   2          1               2        303                   Sales
# 212   2          1               1        234  Research & Development
# 213   2          1               2        370  Research & Development
# 214   1          1               2        920         Human Resources
# 215   3          1               2        261  Research & Development
# 216   2          1               2        359         Human Resources
# 217   1          1               2        350         Human Resources
# 218   2          1               2        414                   Sales
# 219   1          1               1        459  Research & Development
# 220   3          1               2       1254                   Sales
# 221   1          1               2        945                   Sales
# 222   1          1               2        391  Research & Development
# 223   2          1               3        967  Research & Development
# 224   3          1               2       1162  Research & Development
# 225   1          1               1        746                   Sales
# 226   1          1               2       1475                   Sales
# 227   2          1               1        238  Research & Development
# 228   1          1               1       1337         Human Resources
# 229   1          1               2       1404  Research & Development
# 230   2          1               1        754                   Sales
# 231   3          1               2       1168                   Sales
# 232   1          1               1        638                   Sales
# 233   1          1               2       1092  Research & Development
# 234   3          1               2        310  Research & Development
# 235   3          1               1        878                   Sales
# 236   3          1               2        410                   Sales
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                   1          2     Life Sciences              1
# 1                   2          2             Other              1
# 2                  24          3     Life Sciences              1
# 3                   9          4     Life Sciences              1
# 4                   6          1           Medical              1
# 5                  16          1     Life Sciences              1
# 6                   5          3  Technical Degree              1
# 7                   1          3           Medical              1
# 8                   3          2         Marketing              1
# 9                  25          3     Life Sciences              1
# 10                 12          3  Technical Degree              1
# 11                  1          2     Life Sciences              1
# 12                  5          4  Technical Degree              1
# 13                  9          3           Medical              1
# 14                  9          2           Medical              1
# 15                  6          4   Human Resources              1
# 16                  6          3     Life Sciences              1
# 17                  5          3         Marketing              1
# 18                  7          3     Life Sciences              1
# 19                 14          4     Life Sciences              1
# 20                  6          4     Life Sciences              1
# 21                 23          4           Medical              1
# 22                 22          1         Marketing              1
# 23                 20          3     Life Sciences              1
# 24                  8          4     Life Sciences              1
# 25                  9          3           Medical              1
# 26                  1          1  Technical Degree              1
# 27                  2          3     Life Sciences              1
# 28                 20          2         Marketing              1
# 29                 23          2     Life Sciences              1
# ..                ...        ...               ...            ...
# 207                17          3  Technical Degree              1
# 208                 7          1         Marketing              1
# 209                 8          1           Medical              1
# 210                 1          2           Medical              1
# 211                27          3     Life Sciences              1
# 212                 9          4     Life Sciences              1
# 213                10          4           Medical              1
# 214                20          2           Medical              1
# 215                21          2           Medical              1
# 216                18          5   Human Resources              1
# 217                13          3   Human Resources              1
# 218                 2          4         Marketing              1
# 219                24          2     Life Sciences              1
# 220                10          3     Life Sciences              1
# 221                 9          3           Medical              1
# 222                 7          1     Life Sciences              1
# 223                16          4  Technical Degree              1
# 224                24          2     Life Sciences              1
# 225                24          3  Technical Degree              1
# 226                13          2         Marketing              1
# 227                 5          2     Life Sciences              1
# 228                22          3   Human Resources              1
# 229                17          3  Technical Degree              1
# 230                26          4         Marketing              1
# 231                24          4     Life Sciences              1
# 232                 9          3         Marketing              1
# 233                 1          4           Medical              1
# 234                 7          2  Technical Degree              1
# 235                 1          4     Life Sciences              1
# 236                28          3         Marketing              1
#
#      EmployeeNumber   ...    StandardHours StockOptionLevel  \
# 0                 1   ...               80                0
# 1                 4   ...               80                0
# 2                19   ...               80                0
# 3                27   ...               80                0
# 4                31   ...               80                0
# 5                33   ...               80                0
# 6                42   ...               80                1
# 7                45   ...               80                1
# 8                47   ...               80                0
# 9                55   ...               80                0
# 10               58   ...               80                0
# 11               64   ...               80                0
# 12               65   ...               80                0
# 13               90   ...               80                1
# 14              118   ...               80                0
# 15              133   ...               80                0
# 16              137   ...               80                0
# 17              142   ...               80                0
# 18              147   ...               80                0
# 19              161   ...               80                3
# 20              163   ...               80                0
# 21              165   ...               80                1
# 22              167   ...               80                0
# 23              175   ...               80                1
# 24              179   ...               80                0
# 25              190   ...               80                0
# 26              235   ...               80                0
# 27              243   ...               80                0
# 28              248   ...               80                0
# 29              261   ...               80                0
# ..              ...   ...              ...              ...
# 207            1767   ...               80                1
# 208            1780   ...               80                0
# 209            1783   ...               80                0
# 210            1792   ...               80                3
# 211            1797   ...               80                0
# 212            1807   ...               80                1
# 213            1809   ...               80                0
# 214            1818   ...               80                0
# 215            1821   ...               80                1
# 216            1842   ...               80                0
# 217            1844   ...               80                3
# 218            1862   ...               80                0
# 219            1868   ...               80                0
# 220            1869   ...               80                3
# 221            1876   ...               80                0
# 222            1878   ...               80                0
# 223            1905   ...               80                1
# 224            1907   ...               80                0
# 225            1928   ...               80                0
# 226            1933   ...               80                0
# 227            1939   ...               80                0
# 228            1944   ...               80                0
# 229            1960   ...               80                1
# 230            1967   ...               80                0
# 231            1968   ...               80                0
# 232            2023   ...               80                1
# 233            2027   ...               80                3
# 234            2032   ...               80                1
# 235            2044   ...               80                2
# 236            2055   ...               80                1
#
#      TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# 0                    8                      0                1              6
# 1                    7                      3                3              0
# 2                    6                      4                3              4
# 3                   10                      4                3              5
# 4                    8                      2                3              4
# 5                   10                      5                3             10
# 6                   19                      6                4              1
# 7                    6                      2                2              2
# 8                    3                      2                3              3
# 9                    1                      2                2              1
# 10                  23                      0                3             22
# 11                  23                      2                3              1
# 12                   2                      3                2              2
# 13                   2                      0                2              1
# 14                   9                      3                3              9
# 15                   7                      3                3              3
# 16                   1                      5                3              1
# 17                   6                      1                3              6
# 18                   9                      3                3              9
# 19                   7                      2                3              5
# 20                  12                      3                2              7
# 21                  40                      3                2             40
# 22                   0                      2                2              0
# 23                   4                      2                3              2
# 24                  18                      2                3              4
# 25                  10                      2                4              5
# 26                   1                      5                4              0
# 27                   1                      3                2              1
# 28                   4                      5                2              4
# 29                   8                      1                3              1
# ..                 ...                    ...              ...            ...
# 207                  6                      4                3              1
# 208                  1                      3                3              1
# 209                  1                      6                3              1
# 210                  6                      2                2              5
# 211                 10                      2                3             10
# 212                 11                      3                2              7
# 213                 10                      4                1             10
# 214                  6                      3                3              5
# 215                 13                      2                4              9
# 216                  2                      4                3              1
# 217                  4                      3                3              2
# 218                  7                      3                2              2
# 219                  1                      3                2              1
# 220                 14                      2                3              8
# 221                  1                      3                2              1
# 222                  1                      2                3              1
# 223                  5                      2                3              5
# 224                  5                      3                3              4
# 225                  1                      3                3              1
# 226                  6                      0                3              2
# 227                  8                      2                3              4
# 228                  1                      2                3              1
# 229                  6                      2                2              4
# 230                 10                      4                3             10
# 231                 15                      2                2              2
# 232                  1                      3                2              1
# 233                  4                      3                4              2
# 234                 14                      4                1             10
# 235                 12                      3                3              6
# 236                 20                      3                3              3
#
#      YearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager  MarcaA
# 0                     4                       0                     5       1
# 1                     0                       0                     0       1
# 2                     2                       0                     3       1
# 3                     3                       0                     3       1
# 4                     2                       1                     3       1
# 5                     2                       6                     7       1
# 6                     0                       0                     0       1
# 7                     0                       2                     0       1
# 8                     2                       0                     2       1
# 9                     0                       0                     1       1
# 10                   15                      15                     8       1
# 11                    0                       0                     0       1
# 12                    2                       2                     2       1
# 13                    0                       0                     0       1
# 14                    8                       4                     7       1
# 15                    2                       0                     2       1
# 16                    0                       1                     0       1
# 17                    4                       0                     3       1
# 18                    7                       0                     6       1
# 19                    4                       4                     3       1
# 20                    7                       7                     7       1
# 21                   10                      15                     6       1
# 22                    0                       0                     0       1
# 23                    2                       2                     2       1
# 24                    2                       0                     3       1
# 25                    4                       0                     4       1
# 26                    0                       0                     0       1
# 27                    0                       1                     0       1
# 28                    3                       0                     2       1
# 29                    0                       0                     1       1
# ..                  ...                     ...                   ...     ...
# 207                   0                       0                     0       1
# 208                   0                       1                     0       1
# 209                   0                       0                     0       1
# 210                   3                       2                     3       1
# 211                   7                       7                     7       1
# 212                   1                       0                     7       1
# 213                   3                       0                     8       1
# 214                   1                       1                     4       1
# 215                   7                       3                     7       1
# 216                   0                       0                     0       1
# 217                   2                       2                     0       1
# 218                   2                       2                     2       1
# 219                   0                       1                     0       1
# 220                   7                       0                     7       1
# 221                   0                       0                     0       1
# 222                   0                       0                     0       1
# 223                   2                       3                     0       1
# 224                   2                       1                     0       1
# 225                   0                       0                     0       1
# 226                   0                       2                     2       1
# 227                   1                       0                     3       1
# 228                   0                       0                     0       1
# 229                   1                       0                     3       1
# 230                   7                       0                     8       1
# 231                   2                       2                     2       1
# 232                   0                       1                     0       1
# 233                   2                       2                     2       1
# 234                   9                       9                     8       1
# 235                   3                       0                     1       1
# 236                   2                       2                     0       1
#
# [237 rows x 36 columns]

# %%
#CON ESTO GENERO UNA IDEA DE CUALES SON LOS CAMPOS DE ESTUDIO COM MAS EMPLEADOS.
sb.factorplot('EducationField',data=attrition,kind="count")

# %%
attrition['EducationField'].value_counts()
# Out:
# Life Sciences       89
# Medical             63
# Marketing           35
# Technical Degree    32
# Other               11
# Human Resources      7
# Name: EducationField, dtype: int64

# %%
#AGRUPO LAS TABLAS CON REFERENCIA CRUZADA
pd.crosstab(attrition.EducationField, attrition.Department)
# Out:
# Department        Human Resources  Research & Development  Sales
# EducationField
# Human Resources                 7                       0      0
# Life Sciences                   1                      59     29
# Marketing                       0                       0     35
# Medical                         2                      47     14
# Other                           0                       7      4
# Technical Degree                2                      20     10

# %%
EducationField_Department_Attrition_df = attrition.groupby(['EducationField','Department'])['Attrition'].sum()
EducationField_Department_Attrition_df
# Out:
# EducationField    Department
# Human Resources   Human Resources            7
# Life Sciences     Human Resources            1
#                   Research & Development    59
#                   Sales                     29
# Marketing         Sales                     35
# Medical           Human Resources            2
#                   Research & Development    47
#                   Sales                     14
# Other             Research & Development     7
#                   Sales                      4
# Technical Degree  Human Resources            2
#                   Research & Development    20
#                   Sales                     10
# Name: Attrition, dtype: int64

# %%
#Nombre de las columnas
names = attrition.columns.values
names
# Out:
# array(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'MarcaA'],
#       dtype=object)

# %%
df = attrition[[names[2]]]
print df.describe()
df.hist(bins=20);
# Out:
#        BusinessTravel
# count      237.000000
# mean         1.759494
# std          0.533977
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          3.000000

# %%
attrition['BusinessTravel'].value_counts()
# Out:
# 2    156
# 1     69
# 3     12
# Name: BusinessTravel, dtype: int64

# %%
#Todo Tipo
f = open('WA_Fn-UseC_-HR-Employee-Attrition.csv', 'rU')
todotipo = pd.read_csv(f)
#todotipo = todotipo.drop('Unnamed: 0', 1)
todotipo = todotipo[col_reg]
todotipo['Marcab'] = 0

#Eliminar valores perdidos
todotipo = todotipo.dropna()
#Eliminar duplicados
todotipo = todotipo.drop_duplicates(subset=col_reg[1:][:-1], keep='last')
todotipo.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#     ...    StandardHours StockOptionLevel  TotalWorkingYears  \
# 0   ...               80                0                  8
# 1   ...               80                1                 10
# 2   ...               80                0                  7
# 3   ...               80                0                  8
# 4   ...               80                1                  6
#
#    TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                      0                1              6                   4
# 1                      3                3             10                   7
# 2                      3                3              0                   0
# 3                      3                3              8                   7
# 4                      3                3              2                   2
#
#   YearsSinceLastPromotion  YearsWithCurrManager  Marcab
# 0                       0                     5       0
# 1                       1                     7       0
# 2                       0                     0       0
# 3                       3                     0       0
# 4                       2                     2       0
#
# [5 rows x 36 columns]

# %%
#GENERO UN RANGO ESTARIO CON 1=(18-30); 2=(31-45); 3=(46-60). 
bins = [18,30,45,60]
names = ["1","2","3"]
todotipo["Age"] = pd.cut(todotipo["Age"], bins, labels = names)

# %%
#CON ESTO REMPLAZAMOS LOS NOMBRES DE BUSINESSTRAVEL Travel_Frequently(1) ;Travel_Rarely(2) ;Non-Travel(3)
#ATTRITION POR Yes(2); No(0).
todotipo.replace({'BusinessTravel': {"Travel_Frequently": 1,"Travel_Rarely": 2, "Non-Travel": 3 }},  inplace = True)
todotipo.replace({'Attrition' : {"Yes" : 1, "No" : 0}}, inplace = True)
todotipo
# Out:
#      Age  Attrition  BusinessTravel  DailyRate              Department  \
# 0      2          1               2       1102                   Sales
# 1      3          0               1        279  Research & Development
# 2      2          1               2       1373  Research & Development
# 3      2          0               1       1392  Research & Development
# 4      1          0               2        591  Research & Development
# 5      2          0               1       1005  Research & Development
# 6      3          0               2       1324  Research & Development
# 7      1          0               2       1358  Research & Development
# 8      2          0               1        216  Research & Development
# 9      2          0               2       1299  Research & Development
# 10     2          0               2        809  Research & Development
# 11     1          0               2        153  Research & Development
# 12     2          0               2        670  Research & Development
# 13     2          0               2       1346  Research & Development
# 14     1          1               2        103  Research & Development
# 15     1          0               2       1389  Research & Development
# 16     2          0               2        334  Research & Development
# 17     1          0               3       1123  Research & Development
# 18     3          0               2       1219                   Sales
# 19     2          0               2        371  Research & Development
# 20     1          0               3        673  Research & Development
# 21     2          1               2       1218                   Sales
# 22     2          0               2        419  Research & Development
# 23     1          0               2        391  Research & Development
# 24     2          1               2        699  Research & Development
# 25     3          0               2       1282  Research & Development
# 26     2          1               1       1125  Research & Development
# 27     2          0               2        691                   Sales
# 28     2          0               2        477  Research & Development
# 29     3          0               2        705                   Sales
# ...   ..        ...             ...        ...                     ...
# 1440   2          0               1        688  Research & Development
# 1441   3          0               3        667  Research & Development
# 1442   1          1               2       1092  Research & Development
# 1443   2          0               2        300  Research & Development
# 1444   3          1               2        310  Research & Development
# 1445   2          0               2        582  Research & Development
# 1446   2          0               2        704                   Sales
# 1447   2          0               3        301                   Sales
# 1448   2          0               2        930                   Sales
# 1449   2          0               2        529  Research & Development
# 1450   2          0               2       1146         Human Resources
# 1451   2          0               2        345                   Sales
# 1452   3          1               1        878                   Sales
# 1453   2          0               2       1120                   Sales
# 1454   2          0               2        374                   Sales
# 1455   2          0               2       1322  Research & Development
# 1456   2          0               1       1199  Research & Development
# 1457   2          0               2       1194  Research & Development
# 1458   2          0               2        287  Research & Development
# 1459   1          0               2       1378  Research & Development
# 1460   1          0               2        468  Research & Development
# 1461   3          1               2        410                   Sales
# 1462   2          0               2        722                   Sales
# 1463   2          0               3        325  Research & Development
# 1464   1          0               2       1167                   Sales
# 1465   2          0               1        884  Research & Development
# 1466   2          0               2        613  Research & Development
# 1467   1          0               2        155  Research & Development
# 1468   3          0               1       1023                   Sales
# 1469   2          0               2        628  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                    1          2     Life Sciences              1
# 1                    8          1     Life Sciences              1
# 2                    2          2             Other              1
# 3                    3          4     Life Sciences              1
# 4                    2          1           Medical              1
# 5                    2          2     Life Sciences              1
# 6                    3          3           Medical              1
# 7                   24          1     Life Sciences              1
# 8                   23          3     Life Sciences              1
# 9                   27          3           Medical              1
# 10                  16          3           Medical              1
# 11                  15          2     Life Sciences              1
# 12                  26          1     Life Sciences              1
# 13                  19          2           Medical              1
# 14                  24          3     Life Sciences              1
# 15                  21          4     Life Sciences              1
# 16                   5          2     Life Sciences              1
# 17                  16          2           Medical              1
# 18                   2          4     Life Sciences              1
# 19                   2          3     Life Sciences              1
# 20                  11          2             Other              1
# 21                   9          4     Life Sciences              1
# 22                   7          4     Life Sciences              1
# 23                  15          2     Life Sciences              1
# 24                   6          1           Medical              1
# 25                   5          3             Other              1
# 26                  16          1     Life Sciences              1
# 27                   8          4         Marketing              1
# 28                   7          4           Medical              1
# 29                   2          4         Marketing              1
# ...                ...        ...               ...            ...
# 1440                 4          2     Life Sciences              1
# 1441                 1          4     Life Sciences              1
# 1442                 1          4           Medical              1
# 1443                 2          3     Life Sciences              1
# 1444                 7          2  Technical Degree              1
# 1445                28          4     Life Sciences              1
# 1446                28          3         Marketing              1
# 1447                15          4         Marketing              1
# 1448                 3          3     Life Sciences              1
# 1449                 2          3  Technical Degree              1
# 1450                26          4     Life Sciences              1
# 1451                10          2     Life Sciences              1
# 1452                 1          4     Life Sciences              1
# 1453                11          4         Marketing              1
# 1454                20          3     Life Sciences              1
# 1455                 2          4     Life Sciences              1
# 1456                18          4     Life Sciences              1
# 1457                 2          4           Medical              1
# 1458                 1          4     Life Sciences              1
# 1459                13          2             Other              1
# 1460                28          4           Medical              1
# 1461                28          3         Marketing              1
# 1462                24          1         Marketing              1
# 1463                 5          3           Medical              1
# 1464                 5          3             Other              1
# 1465                23          2           Medical              1
# 1466                 6          1           Medical              1
# 1467                 4          3     Life Sciences              1
# 1468                 2          3           Medical              1
# 1469                 8          3           Medical              1
#
#       EmployeeNumber   ...    StandardHours StockOptionLevel  \
# 0                  1   ...               80                0
# 1                  2   ...               80                1
# 2                  4   ...               80                0
# 3                  5   ...               80                0
# 4                  7   ...               80                1
# 5                  8   ...               80                0
# 6                 10   ...               80                3
# 7                 11   ...               80                1
# 8                 12   ...               80                0
# 9                 13   ...               80                2
# 10                14   ...               80                1
# 11                15   ...               80                0
# 12                16   ...               80                1
# 13                18   ...               80                1
# 14                19   ...               80                0
# 15                20   ...               80                1
# 16                21   ...               80                2
# 17                22   ...               80                2
# 18                23   ...               80                0
# 19                24   ...               80                0
# 20                26   ...               80                1
# 21                27   ...               80                0
# 22                28   ...               80                0
# 23                30   ...               80                0
# 24                31   ...               80                0
# 25                32   ...               80                1
# 26                33   ...               80                0
# 27                35   ...               80                1
# 28                36   ...               80                1
# 29                38   ...               80                0
# ...              ...   ...              ...              ...
# 1440            2025   ...               80                3
# 1441            2026   ...               80                1
# 1442            2027   ...               80                3
# 1443            2031   ...               80                0
# 1444            2032   ...               80                1
# 1445            2034   ...               80                1
# 1446            2035   ...               80                2
# 1447            2036   ...               80                1
# 1448            2037   ...               80                1
# 1449            2038   ...               80                0
# 1450            2040   ...               80                0
# 1451            2041   ...               80                1
# 1452            2044   ...               80                2
# 1453            2045   ...               80                1
# 1454            2046   ...               80                0
# 1455            2048   ...               80                0
# 1456            2049   ...               80                2
# 1457            2051   ...               80                3
# 1458            2052   ...               80                1
# 1459            2053   ...               80                1
# 1460            2054   ...               80                0
# 1461            2055   ...               80                1
# 1462            2056   ...               80                1
# 1463            2057   ...               80                0
# 1464            2060   ...               80                0
# 1465            2061   ...               80                1
# 1466            2062   ...               80                1
# 1467            2064   ...               80                1
# 1468            2065   ...               80                0
# 1469            2068   ...               80                0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# 5                     8                      2                2
# 6                    12                      3                2
# 7                     1                      2                3
# 8                    10                      2                3
# 9                    17                      3                2
# 10                    6                      5                3
# 11                   10                      3                3
# 12                    5                      1                2
# 13                    3                      2                3
# 14                    6                      4                3
# 15                   10                      1                3
# 16                    7                      5                2
# 17                    1                      2                2
# 18                   31                      3                3
# 19                    6                      3                3
# 20                    5                      5                2
# 21                   10                      4                3
# 22                   13                      4                3
# 23                    0                      6                3
# 24                    8                      2                3
# 25                   26                      3                2
# 26                   10                      5                3
# 27                   10                      2                3
# 28                   24                      4                3
# 29                   22                      2                2
# ...                 ...                    ...              ...
# 1440                 18                      3                3
# 1441                 13                      2                2
# 1442                  4                      3                4
# 1443                 24                      2                2
# 1444                 14                      4                1
# 1445                 21                      3                3
# 1446                  8                      2                3
# 1447                 15                      4                2
# 1448                 14                      5                3
# 1449                  4                      4                3
# 1450                  9                      2                3
# 1451                 10                      1                3
# 1452                 12                      3                3
# 1453                  8                      2                2
# 1454                  8                      3                3
# 1455                  8                      2                3
# 1456                 10                      2                4
# 1457                 20                      2                3
# 1458                  4                      5                3
# 1459                 10                      2                3
# 1460                  5                      3                1
# 1461                 20                      3                3
# 1462                 21                      2                2
# 1463                 10                      2                3
# 1464                  5                      2                3
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#      YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 0                 6                   4                       0
# 1                10                   7                       1
# 2                 0                   0                       0
# 3                 8                   7                       3
# 4                 2                   2                       2
# 5                 7                   7                       3
# 6                 1                   0                       0
# 7                 1                   0                       0
# 8                 9                   7                       1
# 9                 7                   7                       7
# 10                5                   4                       0
# 11                9                   5                       0
# 12                5                   2                       4
# 13                2                   2                       1
# 14                4                   2                       0
# 15               10                   9                       8
# 16                6                   2                       0
# 17                1                   0                       0
# 18               25                   8                       3
# 19                3                   2                       1
# 20                4                   2                       1
# 21                5                   3                       0
# 22               12                   6                       2
# 23                0                   0                       0
# 24                4                   2                       1
# 25               14                  13                       4
# 26               10                   2                       6
# 27                9                   7                       4
# 28               22                   6                       5
# 29                2                   2                       2
# ...             ...                 ...                     ...
# 1440              4                   2                       0
# 1441             13                  12                       1
# 1442              2                   2                       2
# 1443             22                   6                       4
# 1444             10                   9                       9
# 1445             20                   7                       0
# 1446              8                   7                       1
# 1447             15                  12                      11
# 1448              5                   4                       0
# 1449              4                   2                       1
# 1450              9                   0                       1
# 1451             10                   7                       1
# 1452              6                   3                       0
# 1453              6                   3                       0
# 1454              5                   3                       0
# 1455              2                   2                       2
# 1456             10                   2                       0
# 1457              5                   3                       0
# 1458              4                   3                       1
# 1459              4                   3                       0
# 1460              5                   4                       0
# 1461              3                   2                       2
# 1462             20                   9                       9
# 1463              9                   4                       1
# 1464              4                   2                       0
# 1465              5                   2                       0
# 1466              7                   7                       1
# 1467              6                   2                       0
# 1468              9                   6                       0
# 1469              4                   3                       1
#
#       YearsWithCurrManager  Marcab
# 0                        5       0
# 1                        7       0
# 2                        0       0
# 3                        0       0
# 4                        2       0
# 5                        6       0
# 6                        0       0
# 7                        0       0
# 8                        8       0
# 9                        7       0
# 10                       3       0
# 11                       8       0
# 12                       3       0
# 13                       2       0
# 14                       3       0
# 15                       8       0
# 16                       5       0
# 17                       0       0
# 18                       7       0
# 19                       2       0
# 20                       3       0
# 21                       3       0
# 22                      11       0
# 23                       0       0
# 24                       3       0
# 25                       8       0
# 26                       7       0
# 27                       2       0
# 28                      17       0
# 29                       1       0
# ...                    ...     ...
# 1440                     2       0
# 1441                     9       0
# 1442                     2       0
# 1443                    14       0
# 1444                     8       0
# 1445                    10       0
# 1446                     7       0
# 1447                    11       0
# 1448                     4       0
# 1449                     2       0
# 1450                     7       0
# 1451                     9       0
# 1452                     1       0
# 1453                     0       0
# 1454                     1       0
# 1455                     2       0
# 1456                     2       0
# 1457                     2       0
# 1458                     1       0
# 1459                     3       0
# 1460                     4       0
# 1461                     0       0
# 1462                     6       0
# 1463                     7       0
# 1464                     0       0
# 1465                     3       0
# 1466                     7       0
# 1467                     3       0
# 1468                     8       0
# 1469                     2       0
#
# [1470 rows x 36 columns]

# %%
df = todotipo[[names[1]]]
print df.describe()
df.hist(bins=90);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-169-b040ae7681ff> in <module>()
# ----> 1 df = todotipo[[names[1]]]
#       2 print df.describe()
#       3 df.hist(bins=90);
#
# /Users/mac/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# /Users/mac/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# /Users/mac/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1267                 if mask.any():
#    1268                     raise KeyError('{mask} not in index'
# -> 1269                                    .format(mask=objarr[mask]))
#    1270
#    1271                 return _values_from_object(indexer)
#
# KeyError: "['2'] not in index"

# %%
todotipo['BusinessTravel'].value_counts()
# Out:
# 2    1043
# 1     277
# 3     150
# Name: BusinessTravel, dtype: int64

# %%
def plot_pie(y):
    target_stats = Counter(y)
    labels = list(target_stats.keys())
    sizes = list(target_stats.values())
    explode = tuple([0.1] * len(target_stats))

    fig, ax = plt.subplots()
    ax.pie(sizes, explode=explode, labels=labels, shadow=True,
           autopct='%1.1f%%')
    ax.axis('equal')
    
def get_hist(var1,var2,values_range=[0,1],nbins=20,normed=True,name_image='2hist.png'):
    
    common_params = dict(bins=nbins,range=values_range,normed=normed)
    plt.subplots_adjust(hspace=.8)
    plt.subplot(311)
    plt.title('Default')
    #plt.hist(df.popularity, **common_params)
    plt.hist(var1, **common_params)
    plt.hist(var2, **common_params)
    plt.subplot(312)
    plt.title('Skinny shift - 2 at a time')
    plt.hist((var1, var2), **common_params)
    plt.subplot(313)
    common_params['histtype'] = 'step'
    plt.title('With steps')
    #plt.hist(df.popularity, **common_params)
    plt.hist(var1, **common_params)
    plt.hist(var2, **common_params)

    plt.savefig(name_image, dpi = 400)
    plt.show()

# %%
len(names)
# Out:
# 3

# %%
name = names[2]
print name
print attrition[name].describe()
df1 = attrition[[name]]
df2 = todotipo[[name]]
get_hist(df1.values,df2.values,values_range=[-10,10])
# Out:
# 3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-174-0125adfe4b75> in <module>()
#       1 name = names[2]
#       2 print name
# ----> 3 print attrition[name].describe()
#       4 df1 = attrition[[name]]
#       5 df2 = todotipo[[name]]
#
# /Users/mac/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Users/mac/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Users/mac/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Users/mac/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Users/mac/anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '3'

# %%
datos_base = pd.concat([attrition, todotipo])
print(datos_base.groupby('Attrition')[name].describe())
datos_base.boxplot(column=name,by='Attrition');
# Out:
#             count      mean       std  min  25%  50%  75%  max
# Attrition
# 0          1233.0  1.943228  0.526895  1.0  2.0  2.0  2.0  3.0
# 1           474.0  1.759494  0.533413  1.0  1.0  2.0  2.0  3.0

# %%
datos_base.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.190808        0.026828   0.015939
# Attrition                -0.190808   1.000000       -0.153872  -0.068981
# BusinessTravel            0.026828  -0.153872        1.000000   0.030630
# DailyRate                 0.015939  -0.068981        0.030630   1.000000
# DistanceFromHome         -0.003892   0.094181        0.010091  -0.018389
# Education                 0.207111  -0.038287        0.009764  -0.019926
# EmployeeCount                  NaN        NaN             NaN        NaN
# EmployeeNumber           -0.000835  -0.012947        0.007529  -0.049242
# EnvironmentSatisfaction   0.013822  -0.124269        0.014076   0.016316
# HourlyRate                0.037399  -0.008352        0.007769   0.031389
# JobInvolvement            0.048220  -0.155633       -0.019801   0.048758
# JobLevel                  0.515236  -0.208161        0.033883   0.010713
# JobSatisfaction           0.010500  -0.125400       -0.015414   0.030529
# MarcaA                         NaN        NaN             NaN        NaN
# Marcab                         NaN        NaN             NaN        NaN
# MonthlyIncome             0.503627  -0.198702        0.034167   0.014715
# MonthlyRate               0.012017   0.018446        0.006469  -0.047030
# NumCompaniesWorked        0.300632   0.052412        0.033370   0.044346
# PercentSalaryHike         0.001300  -0.016349        0.033304   0.013383
# PerformanceRating        -0.003475   0.003515        0.004094  -0.001245
# RelationshipSatisfaction  0.068733  -0.055524       -0.000842  -0.000095
# StandardHours                  NaN        NaN             NaN        NaN
# StockOptionLevel          0.066529  -0.165981        0.028458   0.036138
# TotalWorkingYears         0.683860  -0.208664        0.012966   0.018579
# TrainingTimesLastYear    -0.018816  -0.072639       -0.028462   0.002015
# WorkLifeBalance          -0.024078  -0.076048       -0.005402  -0.025463
# YearsAtCompany            0.339951  -0.163436        0.009563  -0.034244
# YearsInCurrentRole        0.246757  -0.197163        0.021746   0.009975
# YearsSinceLastPromotion   0.233897  -0.040328       -0.003973  -0.036614
# YearsWithCurrManager      0.231196  -0.191799        0.013684  -0.020036
#
#                           DistanceFromHome  Education  EmployeeCount  \
# Age                              -0.003892   0.207111            NaN
# Attrition                         0.094181  -0.038287            NaN
# BusinessTravel                    0.010091   0.009764            NaN
# DailyRate                        -0.018389  -0.019926            NaN
# DistanceFromHome                  1.000000   0.022831            NaN
# Education                         0.022831   1.000000            NaN
# EmployeeCount                          NaN        NaN            NaN
# EmployeeNumber                    0.035558   0.047273            NaN
# EnvironmentSatisfaction          -0.015529  -0.026481            NaN
# HourlyRate                        0.024363   0.017824            NaN
# JobInvolvement                    0.007293   0.054912            NaN
# JobLevel                          0.006675   0.105155            NaN
# JobSatisfaction                  -0.014823  -0.018141            NaN
# MarcaA                                 NaN        NaN            NaN
# Marcab                                 NaN        NaN            NaN
# MonthlyIncome                    -0.018291   0.098165            NaN
# MonthlyRate                       0.026305  -0.023402            NaN
# NumCompaniesWorked               -0.041089   0.115139            NaN
# PercentSalaryHike                 0.053824  -0.007151            NaN
# PerformanceRating                 0.038108  -0.022909            NaN
# RelationshipSatisfaction          0.009652   0.005075            NaN
# StandardHours                          NaN        NaN            NaN
# StockOptionLevel                  0.035227   0.027857            NaN
# TotalWorkingYears                -0.003732   0.152947            NaN
# TrainingTimesLastYear            -0.040261  -0.029152            NaN
# WorkLifeBalance                  -0.034864  -0.006352            NaN
# YearsAtCompany                   -0.002396   0.083025            NaN
# YearsInCurrentRole                0.003211   0.068244            NaN
# YearsSinceLastPromotion           0.006025   0.066507            NaN
# YearsWithCurrManager              0.003584   0.079280            NaN
#
#                           EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# Age                            -0.000835                 0.013822    0.037399
# Attrition                      -0.012947                -0.124269   -0.008352
# BusinessTravel                  0.007529                 0.014076    0.007769
# DailyRate                      -0.049242                 0.016316    0.031389
# DistanceFromHome                0.035558                -0.015529    0.024363
# Education                       0.047273                -0.026481    0.017824
# EmployeeCount                        NaN                      NaN         NaN
# EmployeeNumber                  1.000000                 0.022321    0.039116
# EnvironmentSatisfaction         0.022321                 1.000000   -0.045130
# HourlyRate                      0.039116                -0.045130    1.000000
# JobInvolvement                  0.010013                 0.015755    0.046841
# JobLevel                       -0.013695                 0.001698   -0.021149
# JobSatisfaction                -0.054370                 0.007714   -0.078042
# MarcaA                               NaN                      NaN         NaN
# Marcab                               NaN                      NaN         NaN
# MonthlyIncome                  -0.011999                -0.005394   -0.011244
# MonthlyRate                     0.008890                 0.035814   -0.015414
# NumCompaniesWorked             -0.001734                -0.018036    0.017472
# PercentSalaryHike              -0.020151                -0.018306   -0.016040
# PerformanceRating              -0.022220                -0.025533   -0.007582
# RelationshipSatisfaction       -0.070745                 0.009415    0.005385
# StandardHours                        NaN                      NaN         NaN
# StockOptionLevel                0.073791                 0.001043    0.034215
# TotalWorkingYears              -0.011992                 0.000682    0.002584
# TrainingTimesLastYear           0.012247                -0.007649    0.000703
# WorkLifeBalance                 0.010759                 0.010503   -0.014618
# YearsAtCompany                 -0.007938                 0.014208   -0.014233
# YearsInCurrentRole             -0.007891                 0.026548   -0.026060
# YearsSinceLastPromotion        -0.005750                 0.030905   -0.034835
# YearsWithCurrManager           -0.006610                 0.005748   -0.018235
#
#                                   ...           RelationshipSatisfaction  \
# Age                               ...                           0.068733
# Attrition                         ...                          -0.055524
# BusinessTravel                    ...                          -0.000842
# DailyRate                         ...                          -0.000095
# DistanceFromHome                  ...                           0.009652
# Education                         ...                           0.005075
# EmployeeCount                     ...                                NaN
# EmployeeNumber                    ...                          -0.070745
# EnvironmentSatisfaction           ...                           0.009415
# HourlyRate                        ...                           0.005385
# JobInvolvement                    ...                           0.036424
# JobLevel                          ...                           0.032193
# JobSatisfaction                   ...                           0.006168
# MarcaA                            ...                                NaN
# Marcab                            ...                                NaN
# MonthlyIncome                     ...                           0.037660
# MonthlyRate                       ...                           0.003826
# NumCompaniesWorked                ...                           0.059102
# PercentSalaryHike                 ...                          -0.045394
# PerformanceRating                 ...                          -0.033112
# RelationshipSatisfaction          ...                           1.000000
# StandardHours                     ...                                NaN
# StockOptionLevel                  ...                          -0.033896
# TotalWorkingYears                 ...                           0.034306
# TrainingTimesLastYear             ...                           0.004390
# WorkLifeBalance                   ...                           0.006635
# YearsAtCompany                    ...                           0.030496
# YearsInCurrentRole                ...                          -0.000095
# YearsSinceLastPromotion           ...                           0.042229
# YearsWithCurrManager              ...                           0.006454
#
#                           StandardHours  StockOptionLevel  TotalWorkingYears  \
# Age                                 NaN          0.066529           0.683860
# Attrition                           NaN         -0.165981          -0.208664
# BusinessTravel                      NaN          0.028458           0.012966
# DailyRate                           NaN          0.036138           0.018579
# DistanceFromHome                    NaN          0.035227          -0.003732
# Education                           NaN          0.027857           0.152947
# EmployeeCount                       NaN               NaN                NaN
# EmployeeNumber                      NaN          0.073791          -0.011992
# EnvironmentSatisfaction             NaN          0.001043           0.000682
# HourlyRate                          NaN          0.034215           0.002584
# JobInvolvement                      NaN          0.035668           0.010482
# JobLevel                            NaN          0.034301           0.781600
# JobSatisfaction                     NaN          0.029217          -0.006633
# MarcaA                              NaN               NaN                NaN
# Marcab                              NaN               NaN                NaN
# MonthlyIncome                       NaN          0.024219           0.772664
# MonthlyRate                         NaN         -0.042504           0.016104
# NumCompaniesWorked                  NaN          0.043588           0.238233
# PercentSalaryHike                   NaN          0.002320          -0.028341
# PerformanceRating                   NaN         -0.007687          -0.001194
# RelationshipSatisfaction            NaN         -0.033896           0.034306
# StandardHours                       NaN               NaN                NaN
# StockOptionLevel                    NaN          1.000000           0.034339
# TotalWorkingYears                   NaN          0.034339           1.000000
# TrainingTimesLastYear               NaN          0.016296          -0.033541
# WorkLifeBalance                     NaN          0.022658           0.003521
# YearsAtCompany                      NaN          0.029889           0.650328
# YearsInCurrentRole                  NaN          0.058555           0.487766
# YearsSinceLastPromotion             NaN          0.015520           0.420810
# YearsWithCurrManager                NaN          0.035717           0.480888
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                   -0.018816        -0.024078
# Attrition                             -0.072639        -0.076048
# BusinessTravel                        -0.028462        -0.005402
# DailyRate                              0.002015        -0.025463
# DistanceFromHome                      -0.040261        -0.034864
# Education                             -0.029152        -0.006352
# EmployeeCount                               NaN              NaN
# EmployeeNumber                         0.012247         0.010759
# EnvironmentSatisfaction               -0.007649         0.010503
# HourlyRate                             0.000703        -0.014618
# JobInvolvement                        -0.020125        -0.000360
# JobLevel                              -0.020484         0.037016
# JobSatisfaction                       -0.004979        -0.018911
# MarcaA                                      NaN              NaN
# Marcab                                      NaN              NaN
# MonthlyIncome                         -0.024430         0.033043
# MonthlyRate                           -0.008471         0.003704
# NumCompaniesWorked                    -0.056821        -0.017231
# PercentSalaryHike                     -0.003914         0.005903
# PerformanceRating                     -0.019995         0.012474
# RelationshipSatisfaction               0.004390         0.006635
# StandardHours                               NaN              NaN
# StockOptionLevel                       0.016296         0.022658
# TotalWorkingYears                     -0.033541         0.003521
# TrainingTimesLastYear                  1.000000         0.036444
# WorkLifeBalance                        0.036444         1.000000
# YearsAtCompany                         0.004611         0.010425
# YearsInCurrentRole                    -0.009350         0.054015
# YearsSinceLastPromotion               -0.013741         0.000898
# YearsWithCurrManager                  -0.006374         0.001596
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Age                             0.339951            0.246757
# Attrition                      -0.163436           -0.197163
# BusinessTravel                  0.009563            0.021746
# DailyRate                      -0.034244            0.009975
# DistanceFromHome               -0.002396            0.003211
# Education                       0.083025            0.068244
# EmployeeCount                        NaN                 NaN
# EmployeeNumber                 -0.007938           -0.007891
# EnvironmentSatisfaction         0.014208            0.026548
# HourlyRate                     -0.014233           -0.026060
# JobInvolvement                 -0.011221            0.018717
# JobLevel                        0.549909            0.415004
# JobSatisfaction                 0.018314            0.015852
# MarcaA                               NaN                 NaN
# Marcab                               NaN                 NaN
# MonthlyIncome                   0.532277            0.393084
# MonthlyRate                    -0.034438           -0.024155
# NumCompaniesWorked             -0.104397           -0.079687
# PercentSalaryHike              -0.041926           -0.009321
# PerformanceRating              -0.005184            0.027169
# RelationshipSatisfaction        0.030496           -0.000095
# StandardHours                        NaN                 NaN
# StockOptionLevel                0.029889            0.058555
# TotalWorkingYears               0.650328            0.487766
# TrainingTimesLastYear           0.004611           -0.009350
# WorkLifeBalance                 0.010425            0.054015
# YearsAtCompany                  1.000000            0.767593
# YearsInCurrentRole              0.767593            1.000000
# YearsSinceLastPromotion         0.628510            0.563580
# YearsWithCurrManager            0.771742            0.726134
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.233897              0.231196
# Attrition                               -0.040328             -0.191799
# BusinessTravel                          -0.003973              0.013684
# DailyRate                               -0.036614             -0.020036
# DistanceFromHome                         0.006025              0.003584
# Education                                0.066507              0.079280
# EmployeeCount                                 NaN                   NaN
# EmployeeNumber                          -0.005750             -0.006610
# EnvironmentSatisfaction                  0.030905              0.005748
# HourlyRate                              -0.034835             -0.018235
# JobInvolvement                          -0.013172              0.038157
# JobLevel                                 0.363787              0.395898
# JobSatisfaction                         -0.001006             -0.013150
# MarcaA                                        NaN                   NaN
# Marcab                                        NaN                   NaN
# MonthlyIncome                            0.358504              0.367986
# MonthlyRate                             -0.010472             -0.053038
# NumCompaniesWorked                      -0.030594             -0.101491
# PercentSalaryHike                       -0.034555             -0.015658
# PerformanceRating                        0.002768              0.019733
# RelationshipSatisfaction                 0.042229              0.006454
# StandardHours                                 NaN                   NaN
# StockOptionLevel                         0.015520              0.035717
# TotalWorkingYears                        0.420810              0.480888
# TrainingTimesLastYear                   -0.013741             -0.006374
# WorkLifeBalance                          0.000898              0.001596
# YearsAtCompany                           0.628510              0.771742
# YearsInCurrentRole                       0.563580              0.726134
# YearsSinceLastPromotion                  1.000000              0.529906
# YearsWithCurrManager                     0.529906              1.000000
#
# [30 rows x 30 columns]

# %%
pd.crosstab(datos_base.Attrition,datos_base.key, margins=True,normalize='index')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-9c2fcb2f51e7> in <module>()
# ----> 1 pd.crosstab(datos_base.Attrition,datos_base.key, margins=True,normalize='index')
#
# /Users/mac/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'key'
